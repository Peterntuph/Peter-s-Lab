# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from ipywidgets import interact, FloatSlider
from keras.models import Sequential, Model
from keras.layers import (Input, Lambda, concatenate, Dense)
from keras.optimizers import SGD, Adam
from keras import metrics
from keras.datasets import mnist
from keras.utils import np_utils
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
#Load
(x_train_0, y_train_0), (x_test_0, y_test_0) = mnist.load_data()

# %%
#Reshape
x_train = x_train_0.reshape(60000, -1)
x_test = x_test_0.reshape(10000, -1)

# %%
#normalization
x_train_norm = x_train
x_train_norm -= x_train_norm.min()
x_train_norm = x_train_norm / x_train_norm.max()

# %%
#VAE 的建立(enncoder)
x = Input(shape=(784,))
enc_1 = Dense(100, activation='sigmoid')
enc_2 = Dense(50, activation='sigmoid')

enc_mean = Dense(2)
enc_log_var = Dense(2)

# %%
#sample
def sampling(args):
    m, v = args
    epsilon = K.random_normal(shape=(2,), mean=0, stddev = 1)
    return m + K.exp(v / 2) * epsilon

# %%
#decoder
dec_1 = Dense(50, activation='sigmoid')
dec_2 = Dense(100, activation='sigmoid')
dec_3 = Dense(784, activation='sigmoid')

# %%
#connect
h1 = enc_1(x)
h2 = enc_2(h1)
h3m = enc_mean(h2)
h3v = enc_log_var(h2)

z = Lambda(sampling, output_shape=(2, ))([h3m, h3v])

dh1 = dec_1(z)
dh2 = dec_2(dh1)
x_hat = dec_3(dh2)

VAE = Model(x, x_hat)
VAE.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Peter\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          78500       input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           5050        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            102         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            102         dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2)            0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           150         lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          5100        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 784)          79184       dense_6[0][0]
# ==================================================================================================
# Total params: 168,188
# Trainable params: 168,188
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Loss function
def loss(x,x_recon):
    recovery_loss = 784 * metrics.binary_crossentropy(x, x_recon)
    kl_loss = - 0.5 * K.sum(1 + h3v - K.square(h3m) - K.exp(h3v), axis= -1)
    return recovery_loss + kl_loss

# %%
VAE.compile(loss= loss, optimizer=Adam())

# %%
VAE.fit(x_train_norm, x_train_norm, batch_size=32, epochs=10)
# Out:
# WARNING:tensorflow:From C:\Users\Peter\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 60000/60000 [==============================] - 18s 308us/step - loss: 203.9687
# Epoch 2/10
# 60000/60000 [==============================] - 16s 264us/step - loss: 189.3635
# Epoch 3/10
# 60000/60000 [==============================] - 16s 267us/step - loss: 184.3408
# Epoch 4/10
# 60000/60000 [==============================] - 17s 280us/step - loss: 177.9056
# Epoch 5/10
# 60000/60000 [==============================] - 16s 273us/step - loss: 166.9283
# Epoch 6/10
# 60000/60000 [==============================] - 13s 210us/step - loss: 161.2772
# Epoch 7/10
# 60000/60000 [==============================] - 12s 207us/step - loss: 157.8844
# Epoch 8/10
# 60000/60000 [==============================] - 13s 209us/step - loss: 155.7695
# Epoch 9/10
# 60000/60000 [==============================] - 14s 227us/step - loss: 154.2642
# Epoch 10/10
# 60000/60000 [==============================] - 16s 274us/step - loss: 153.0185

# %%
#視覺化VAE(encoder)
VAE_Encoder = Model(x, h3m)
VAE_Encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 83,652
# Trainable params: 83,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
h_input = Input(shape=(2, ))
VAE_Decoder = Model(h_input, dec_3(dec_2(dec_1(h_input))))
VAE_Decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                150
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               5100
# _________________________________________________________________
# dense_7 (Dense)              (None, 784)               79184
# =================================================================
# Total params: 84,434
# Trainable params: 84,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
index = np.random.randint(x_test.shape[0], size=1000)
VAE_latent = VAE_Encoder.predict(x_test[index])

# %%
plt.scatter(VAE_latent[:,0], VAE_latent[:,1], c=y_test_0[index], cmap='tab20')
plt.colorbar()

# %%
#視覺化(decoder)
def norm(x):
    t = x
    t -= t.min()
    t /= t.max()
    return t

n = 15
digit_size = 28
gd_x = np.linspace(-4 + 0.05, 4-0.05, n)
gd_y = np.linspace(-4 + 0.05, 4-0.05, n)
fig = np.zeros((digit_size * n, digit_size * n))
for i, yi in enumerate(gd_x):
    for j, xi in enumerate(gd_y):
        z = np.array([[xi, yi]])
        x_dec = VAE_Decoder.predict(z)
        digit = x_dec[0].reshape(digit_size, digit_size)
        fig[(n-i-1) * digit_size : (n-i) * digit_size,
           j * digit_size : (j+1) * digit_size] = norm(digit)
plt.figure(figsize=(10,10))
plt.imshow(fig, cmap='Greys')
plt.axis('off')
# Out:
# (-0.5, 419.5, 419.5, -0.5)
